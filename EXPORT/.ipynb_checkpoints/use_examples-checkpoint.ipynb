# %%
from EDA import *
import pandas as pd
import random
import os

# %%
train_dir = '../data'

# %%
df = pd.read_csv('../data/train.csv')
df
# Out:
#               id                    path  label
# 0     TRAIN_0000  ./train/TRAIN_0000.wav      1
# 1     TRAIN_0001  ./train/TRAIN_0001.wav      2
# 2     TRAIN_0002  ./train/TRAIN_0002.wav      4
# 3     TRAIN_0003  ./train/TRAIN_0003.wav      5
# 4     TRAIN_0004  ./train/TRAIN_0004.wav      4
# ...          ...                     ...    ...
# 4996  TRAIN_4996  ./train/TRAIN_4996.wav      5
# 4997  TRAIN_4997  ./train/TRAIN_4997.wav      0
# 4998  TRAIN_4998  ./train/TRAIN_4998.wav      1
# 4999  TRAIN_4999  ./train/TRAIN_4999.wav      1
# 5000  TRAIN_5000  ./train/TRAIN_5000.wav      4
#
# [5001 rows x 3 columns]

# %%
import librosa
import librosa.display as dsp
from IPython.display import Audio
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
x = random.choice(range(len(df)))
path = os.path.join(train_dir, df['path'][x])

fourier_transform(path)
get_audio(path)
RMS_wave(path)
Mel_s(path)
mfcc(path)
# Out:
# Wav length: 2.635963718820862, Mel_S shape:(100, 265)
# array([[-1.758436  , -1.758436  , -1.758436  , ...,  0.9076107 ,
#          0.9076107 ,  0.9076107 ],
#        [-1.0123255 , -1.0123255 , -1.0123255 , ...,  0.08598871,
#          0.08598871,  0.08598871],
#        [ 0.24975775,  0.24975775,  0.24975775, ..., -1.9701456 ,
#         -1.9701456 , -1.9701456 ],
#        ...,
#        [ 0.39661083,  0.39661083,  0.39661083, ..., -0.49496987,
#         -0.49496987, -0.49496987],
#        [ 0.2083126 ,  0.2083126 ,  0.2083126 , ..., -0.09623555,
#         -0.09623555, -0.09623555],
#        [ 0.7830403 ,  0.7830403 ,  0.7830403 , ...,  0.38816398,
#          0.38816398,  0.38816398]], dtype=float32)

# %%
from augmentations import *

# %%
mel_s = Mel_s(path)
# Out:
# Wav length: 2.635963718820862, Mel_S shape:(100, 265)

# %% [markdown]
# pad_to_size(mel_s, 30000)

# %%
librosa.display.specshow(PadToSize(30000)(mel_s), 
                             sr=16000, 
                             hop_length=80,
                             x_axis='time',
                             y_axis='log')
